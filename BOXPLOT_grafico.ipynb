# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelWars/exercicios-de-aulas/blob/main/BOXPLOT_grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GÁFICO BOX PLOT**

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.DataFrame({'Local':['Bairro 1','Bairro 2'],'Habitantes':[1500,1800],'Homens':[900,400]})
dados.boxplot(column='Homens')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.DataFrame({'Local': ['Bairro 1', 'Bairro 2'],
                      'Habitantes': [1500, 1800],
                      'Homens': [900, 400]})

# Criar boxplots para todas as colunas
plt.figure(figsize=(10, 5))  # Definir tamanho da figura

# Boxplot para a coluna 'Habitantes'
plt.subplot(1, 2, 1)  # Subplot 1
dados.boxplot(column='Habitantes')
plt.title('Boxplot de Habitantes')
plt.ylabel('Habitantes')

# Boxplot para a coluna 'Homens'
plt.subplot(1, 2, 2)  # Subplot 2
dados.boxplot(column='Homens')
plt.title('Boxplot de Homens')
plt.ylabel('Homens')

plt.tight_layout()  # Ajustar o layout

plt.show()

# %%
import matplotlib.pyplot as plt

idades = [17,18,18,19,21,23,25,25,27,35,48]

plt.boxplot(idades)
plt.title('Idades')
plt.xlabel('idade dos alunos')
plt.show()

# %%
import matplotlib.pyplot as plt

idades = [25,30,31,31,35,38,38,39,40,45,77,80]

plt.boxplot(idades)
plt.title('Idades dos alunos')
plt.xlabel('idade')
plt.ylabel('quantidade de alunos')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

idade2= [random.randint(18,77) for _ in range(10)]

plt.boxplot(idade2)
plt.show()
