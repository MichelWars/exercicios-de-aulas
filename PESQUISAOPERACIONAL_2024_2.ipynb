# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelWars/exercicios-de-aulas/blob/main/PESQUISAOPERACIONAL_2024_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Disciplina: PESQUISA OPERACIONAL - CC **

# %% [markdown]
# # Abertura

# %% [markdown]
# **Conjuntos Numéricos**
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Fonte:
# https://www.youtube.com/watch?app=desktop&v=uAN1XktqQCU
#
# https://cursoenemgratuito.com.br/conjuntos-numericos/
#
#
# https://www.todamateria.com.br/conjuntos-numericos/

# %%
# Conjunto de Números Naturais (N)
N_naturais = [1, 2, 3, 4, 5, 20, 7, 8, 9, 10]
print("Conjunto de Números Naturais (N):", N_naturais)

# Conjunto de Números Inteiros (Z)
Z_inteiros = [-10, -9,-8,8,9,10] #list(range(-10, 11))
print("Conjunto de Números Inteiros (Z):", Z_inteiros)

#z n int
# Conjunto de Números Racionais (Q)
Q_racionais = [1/2, -3/4, 2, 5.5]#float double
print("Conjunto de Números Racionais (Q):", Q_racionais)

# Conjunto de Números Reais (R)
import math #NUMERIC oracle
R_reais = [1, -3.5, 2.71828, -math.sqrt(2)]
print("Conjunto de Números Reais (R):", R_reais)

# Conjunto de Números Complexos (I)
I_complexos = [2 + 3j, -1j, 4 - 2j]
print("Conjunto de Números Complexos (I):", I_complexos)
# Out:
# Conjunto de Números Naturais (N): [1, 2, 3, 4, 5, 20, 7, 8, 9, 10]
# Conjunto de Números Inteiros (Z): [-10, -9, -8, 8, 9, 10]
# Conjunto de Números Racionais (Q): [0.5, -0.75, 2, 5.5]
# Conjunto de Números Reais (R): [1, -3.5, 2.71828, -1.4142135623730951]
# Conjunto de Números Complexos (I): [(2+3j), (-0-1j), (4-2j)]

# %% [markdown]
# **Conceitos**
# Determine o conjunto dos números abaixo:
#
# (a) 1/5 - ? Q
#
# (b) 33 - ? N
#
#
# (c) 12j - ? I
#
# (d) -33 - ? Z
#
# (e) raiz de 49 - ? 7 N
#
# (f) PI = 3,141592... - ? R
#
#
# Qual é a diferença entre unidades de medida padrão e não padronizadas?
#
# Padrão : Metro, cubico, kilo, grama, F, C, ... , F(s,d)
#
#
#
#
# Como você calcula a área de um triângulo dado apenas os comprimentos de seus lados?

# %%
1+1

# %% [markdown]
# Operações Básicas
#
# 1 - Calcular a soma de dois números: 10 + 5
#
# 2 - Calcular a diferença de dois números: 10 - 5
#
# 3 - Calcular o produto de dois números: 6 * 4
#
# 4 - Calcular o quociente de dois números : 6 / 4
#
# 5 - Calcular a média de um conjunto de números: 8, 10, 12, 14, 16

# %%
#RESPOSTA

# %% [markdown]
# 6 - Calcular a raiz quadrada de 25, 49 e 201

# %%
import math

# Número para calcular a raiz quadrada
numero = 25

# Calcular a raiz quadrada
raiz_quadrada = math.sqrt(numero)

print("A raiz quadrada de", numero, "é:", raiz_quadrada)

# %% [markdown]
# 7 - Calcule o Desvio padrão de um conjunto de dados : 3,5,7,9,11.
#
#
# **Explicação**
#
#
# "O desvio padrão serve para medir a dispersão dos seus dados. Ele é uma estatística que mede o quanto seus dados se afastam da média - https://www.educamaisbrasil.com.br/enem/matematica/desvio-padrao ".
#
# Veja: https://pt.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/variance-standard-deviation-population/a/calculating-standard-deviation-step-by-step
#
#
# Calcular o desvio padrão de um conjunto de dados: 2, 4, 6, 8, 10.
#
# Exemplo :
#
# ![image.png](data:image/png;base64,...)

# %%
#Codigo

# %% [markdown]
# **Plano Cartesiano - Eixo X e Eixo Y**
#
#
# https://pt.symbolab.com/graphing-calculator/line-slope
#
#
# 8 - Faça as mudanças de y para [2, 3, 5, 7, 11] . Explique o que houve.

# %%
import matplotlib.pyplot as plt

# Dados dos pontos
x_points = [1, 2, 3, 4, 5]
y_points = [1, 2, 3, 4, 5]

# Dados dos intervalos (por exemplo, erros padrão)
#y_err = [0.5, 0.3, 0.4, 0.6, 0.8]

# Criar o gráfico de dispersão com pontos e intervalos de erro
#plt.errorbar(x_points, y_points, yerr=y_err, fmt='o', color='blue', ecolor='red', capsize=5, label='Pontos com intervalos de erro')

plt.plot(x_points, y_points)

# Configurar os rótulos e título
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Pontos com Intervalos de Erro')
plt.legend()

# Exibir o gráfico
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Gráficos da Função**:
# Plotagem de uma Função Linear :  Veja abaixo a f(x)=2x+3.
# f(x)=2x+3 no intervalo de -5 a 5. Exemplo 1. Modifique para a função 15x-1 e explique o que houve.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 3, 7) # Gera interfavo de 0 até 3, com 7 números
print("Os dados gerados aleatórios são: ",x)
y = 2*x + 3

plt.plot(x, y)
plt.errorbar(x, y, x , fmt='o', color='blue', ecolor='red', capsize=5, label='Pontos com intervalos de erro')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfico da função f(x) = 2x + 3')
plt.grid(True)
plt.show()

# %% [markdown]
# **Equação da RETA**
#
#
# Fórmula
# y = m * x + b
# ou
# y = m * x + n
#
# https://pt.symbolab.com/graphing-calculator/line-slope
#
# Digite :
#
# m= lucro POR copo
#
# y= total vendido
#
# x= qtd copos
#
#
# Exemplo:
#
# Você esteja vendendo limonada e quer calcular quanto dinheiro você vai ganhar com base no número de copos vendidos. Você observou que, em média, ganha $5 por copo vendido. Você pode usar a equação da reta para modelar essa relação entre o número de copos vendidos (x) e o dinheiro ganho (y).
#
# **Equação da Reta: y=5x**
#
# Para 1 copo vendido (x = 1), você ganha $5 (y = 5 * 1 = $5).
# Para 2 copos vendidos (x = 2), você ganha $10 (y = 5 * 2 = $10).
# Para 3 copos vendidos (x = 3), você ganha $15 (y = 5 * 3 = $15).
#
#
# A fórmula y = m * x + b
# m= 5
# x= 3
# y= m * x <=> 5 * 3
#
# b ou n = seria um lucro inicial sem vender nada neste caso não temos.
#
#
#
# Essa equação permite que você faça previsões sobre o quanto você ganhará com base no número de copos vendidos, e também ajuda a entender a relação linear entre o número de copos vendidos e o dinheiro ganho.
#
#
# **Álgebra, equação do primeiro grau com 1 variável e com duas variáveis.**
#
# 9 - Calcule o valor de x para a equações lineares abaixo com 1 variável.
#
# a) x + 5 = 3
#
# b) - x + 1 = 7
#
# c) 5x + 2 = 27
#
# d) -x + x - 2x = 10
#
#
#
# **DICA MATEMÁTICA BÁSICA - EQUAÇÃO DO 1º GRAU #04 RESOLUÇÃO DE EXERCÍCIOS \Prof. Gis/** https://www.youtube.com/watch?v=j6dy4VrsFvA
#
# ![image.png](data:image/png;base64,...)

# %%
#Resposta

# %% [markdown]
# **Glossário**
#
#
#
#
#
# expressões =  3 + 1
# algébrica =  3x  + 1
#
#
# expressão alg = 3x + 1
# incógnita = x
#
#
# equação
#
# termo 1 = termo 2
# 3x + 1 = 3x +1
#  5 = 2.5 + 2.5
#  3 = 3 * 1
#  0.5 = 1/2
#
# inequação - desigualdade
#
#  3x + 1 > y - inequação
#  5 + 6x < y - inequação
#  3x + 1 = 7 - equação
#
#  x + g < 5 ?
#   x + 1 >= 6
#  x +1 = 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# variável =
#
# incógnita = é o x, incógnita ? um número que precisa ser descoberto.
#
# constante =
#
# coeficiente = números que aparecem (com operações matemáticas)
#
# função (na matemática) =
#
# função (na programação) =
#
# quociente  = ( n / m) =  resultado da divisão
#
# produto = (n * n) = resultado da multiplicação
#
# razão = resultado de uma divisão
#
# grandeza = unidade de medida, é a definição conceitual da medida de um número, titulo do numero, nome do numero.
# Ex. 60 km, 2500 qtd de peças, 4 pessoas
#  10 dedos da mão
#
# proporção = proporcional , igualdade de termos
#
# termo = uma conta, uma operação matemática
# Ex . 4500x = 180 * 100
#      termo 1 = termo 2
#
# igualdade = quando termos distintos fornecem o mesmo
# resultado.
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
# **Vídeo recomendado**
# https://www.youtube.com/watch?v=EPB2-j4yIbE
#
# **Símbolos Matemáticas:**
# https://www.matematica.pt/util/simbolos.php
#
# **Livro recomendado**
# Paulo Boulos Pré-Calculo (Google)

# %% [markdown]
# # CENÁRIOS - TGS

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# **Equação do primeiro grau**
#
#
# 1. Feira: Se cada maçã custa R$ 2,50 e eu quero comprar 5 maçãs, quanto vou gastar no total?
#
# 2. Mercado: Se um pacote de arroz custa R$ 5,00  e eu tenho R$ 20,00 para gastar, quantos pacotes posso comprar?
#
# 3. Farmácia: Se cada caixa de remédio custa R$ 10,00 e eu preciso comprar 3 caixas, quanto vou gastar no total?
#
# 4. Redes de computadores: Se uma empresa tem 8 servidores e precisa comprar mais 4, quantos servidores terá ao todo?
#
# 5. Sites: Se um site recebe em média 500 visitas por dia, quantas visitas ele terá em uma semana?
#
# 6. Programa mobile: Se um aplicativo ocupa 100MB de espaço e o celular tem 2GB disponíveis, quantos aplicativos desse tamanho podem ser instalados?
#
# 7. Feira: Se cada quilo de tomate custa R$ 3,00 e eu quero comprar 2,5 quilos, quanto vou gastar no total?
#
# 8. Mercado: Se um litro de leite custa R$ 4,00. E  eu tenho R$ 12,00 para gastar, quantos litros posso comprar?
#
# 9. Farmácia: Se cada frasco de xarope custa R$ 8,00 e eu preciso comprar 2 frascos, quanto vou gastar no total?
#
# 10. Redes de computadores: Se uma empresa tem 15 funcionários e precisa comprar computadores para mais 5 funcionários, quantos computadores serão necessários ao todo?
#
# 11. Sites: Se um site tem uma média de 1000 visitas por hora, quantas visitas ele terá em um dia?
#
# 12. Programa mobile: Se um jogo ocupa 500MB de espaço e o celular tem 8GB disponíveis, quantos jogos desse tamanho podem ser instalados?

# %% [markdown]
# # Nova seção

# %% [markdown]
# **Algebra Linear**
#
# 1. *Problema 1 - Compra de Frutas*:
#    Em uma feira, João comprou 3 maçãs e 2 bananas, pagando R$ 10,00. No dia seguinte, ele comprou 2 maçãs e 4 bananas, pagando R$ 14,00. Sabendo que o preço das maçãs é diferente do preço das bananas, qual o preço de cada fruta?
#
#
#    ![image.png](data:image/png;base64,...)
#
#
# -----------------------------------

# %% [markdown]
# **Programação Linear**
#
# Problema P1:
#
# Uma fábrica produz dois tipos de produtos: A e B. Para produzir cada unidade do produto A, são necessárias 2 horas de mão de obra e 1 kg de matéria-prima. Para o produto B, são necessárias 1 hora de mão de obra e 2 kg de matéria-prima. A fábrica dispõe de 40 horas de mão de obra e 30 kg de matéria-prima por dia. O lucro por unidade do produto A é de R$ 10,00 e do produto B, R$ 15,00.
#
# -------------
# Problema P2:
#
# Uma pequena empresa produz dois tipos de produtos: X e Y. Para produzir cada unidade do produto X, são necessárias 3 horas de mão de obra e 2 kg de matéria-prima. Para o produto Y, são necessárias 2 horas de mão de obra e 3 kg de matéria-prima. A empresa dispõe de 60 horas de mão de obra e 50 kg de matéria-prima por semana. O lucro por unidade do produto X é de R$ 20,00 e do produto Y, R$ 25,00.
#
# --------------
# Problema P3:
#
# Uma pequena marcenaria produz dois tipos de móveis: cadeiras e mesas. Para produzir cada cadeira, são necessárias 2 horas de trabalho e 1 metro quadrado de madeira. Para cada mesa, são necessárias 3 horas de trabalho e 2 metros quadrados de madeira. A marcenaria dispõe de 48 horas de trabalho e 30 metros quadrados de madeira por semana. O lucro por cadeira é de R$ 50,00 e por mesa, R$ 80,00.
#
# --------------
#
# **Conceitos**
#
# Operação - (Estratégica, Tática e Operacional)
#
# Restrições
#
# Solução ótima (Max, Min)
#
# Constantes
#
# Variáveis

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir as restrições como funções
def restricao1(x, y):
  return 2*x + 1*y <= 40

def restricao2(x, y):
  return 1*x + 2*y <= 30

# Criar um meshgrid para avaliar as restrições em todos os pontos
x = np.linspace(0, 30, 100)
y = np.linspace(0, 20, 100)
X, Y = np.meshgrid(x, y)

# Avaliar as restrições no meshgrid
Z1 = restricao1(X, Y)
Z2 = restricao2(X, Y)

# Plotar as regiões viáveis
plt.contourf(X, Y, Z1, colors=['white', 'gray'], alpha=0.5)
plt.contourf(X, Y, Z2, colors=['white', 'gray'], alpha=0.5)

# Plotar as linhas das restrições
plt.contour(X, Y, Z1, levels=[0], colors='black')
plt.contour(X, Y, Z2, levels=[0], colors='black')

# Plotar a função objetivo (opcional, para visualizar a direção do aumento)
Z = 10*X + 15*Y
plt.contour(X, Y, Z, levels=[0, 500, 1000, 1500], colors='red')

# Configurar o gráfico
plt.xlabel('x')
plt.ylabel('y')
plt.title('Região Viável e Função Objetivo')
plt.grid(True)
plt.show()
